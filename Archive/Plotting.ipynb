# %%
# Import Packages
import os
from pathlib import Path
import re

import numpy as np
import pandas as pd
import matplotlib

import shutil
import itertools

import nilearn
from nilearn.image import load_img
from nilearn.image import math_img
from nilearn import plotting, datasets
import glob

import nibabel as nib
import nibabel.processing

# %% [markdown]
# # ASD

# %%
# Image Path
image_path = '../ABIDEII/ABIDEII-BNI_1/derivatives/freesurfer/sub-29006/mri/norm.mgz'

# Specify the z-coordinate for the slice (in mm)
z_slice = 18

# Plot the specified z-slice
plotting.plot_anat(image_path, display_mode='z', cut_coords=[z_slice], title='ASD (Age:48)')

# %%
# Image Path
image_path = '../ABIDEII/ABIDEII-BNI_1/derivatives/freesurfer/sub-29007/mri/norm.mgz'

# Specify the z-coordinate for the slice (in mm)
z_slice = 18

# Plot the specified z-slice
plotting.plot_anat(image_path, display_mode='z', cut_coords=[z_slice], title='ASD (Age:41)')

# %% [markdown]
# # Non-ASD

# %%
# Image Path
image_path = '../ABIDEII/ABIDEII-BNI_1/derivatives/freesurfer/sub-29011/mri/norm.mgz'

# Specify the z-coordinate for the slice (in mm)
z_slice = 54

# Plot the specified z-slice
plotting.plot_anat(image_path, display_mode='z', cut_coords=[z_slice], title='Non-ASD (Age:48)')

# %%
# Image Path
image_path = '../ABIDEII/ABIDEII-BNI_1/derivatives/freesurfer/sub-29016/mri/norm.mgz'

# Specify the z-coordinate for the slice (in mm)
z_slice = 36

# Plot the specified z-slice
plotting.plot_anat(image_path, display_mode='z', cut_coords=[z_slice], title='Non-ASD (Age:41)')
